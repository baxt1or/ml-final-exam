# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns",None)

# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/risqaliyevds/uzbek-sentiment-analysis/data/train-00000-of-00001.parquet")

# %%
df = pd.read_parquet("../data/uzum_dataset.parquet", engine='pyarrow')

# %%
df["rating"].value_counts(normalize=True)
# Out:
# rating
# excellent    0.717130
# very poor    0.149220
# good         0.052071
# fair         0.044870
# poor         0.036709
# Name: proportion, dtype: float64
