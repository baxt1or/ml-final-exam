# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns",None)

# %%
df = pd.read_parquet("../data/uzum_dataset.parquet", engine='pyarrow')

# %%
df["rating"].value_counts(normalize=True)
# Out:
# rating
# excellent    0.717130
# very poor    0.149220
# good         0.052071
# fair         0.044870
# poor         0.036709
# Name: proportion, dtype: float64

# %%
df[df['rating'] == 'fair'].iloc[10, 0]
# Out:
# 'noutbook ni oldim rahmat kattakon hozircha juda yaxshi'

# %%
df[df['rating'] == 'very poor']
# Out:
#                                    normalized_review_text     rating
# 11      orqa tor, oldi keng shalvirab g'alati ko'rinyapti  very poor
# 29                                      remishok chiqmadi  very poor
# 33                                              ishlamadi  very poor
# 42                       ishlataman disam chiqib ketvotti  very poor
# 49      umuman yoqmadi. obyom vapshe 0, lipkiy, 2 soat...  very poor
# ...                                                   ...        ...
# 352129                      puliga arzimaykan sifati past  very poor
# 352135                                          brak cqti  very poor
# 352139  assalomu alaykum, uzum jamoasiga alohida rahma...  very poor
# 352141  karobkada ezilgan keldi nojkasi singan. otziv ...  very poor
# 352142  dabdala rasmdagi boshqa menga kelgani boshqa. ...  very poor
#
# [52548 rows x 2 columns]

# %%
df["size"] = df["normalized_review_text"].str.len()

# %%
sorted(df["size"].unique().tolist(), reverse=True)[:15]
# Out:
# [2824,
#  2302,
#  1564,
#  1501,
#  1495,
#  1366,
#  1206,
#  1116,
#  1000,
#  998,
#  980,
#  965,
#  946,
#  908,
#  892]

# %%
df["rating"].unique()
# Out:
# array(['excellent', 'fair', 'very poor', 'good', 'poor'], dtype=object)

# %%
rating_map = {
    'excellent': 5, 
    'good': 4, 
    'fair' : 3,  
    'poor' : 2,
    'very poor' : 1
}

df["rnk"] = df["rating"].map(rating_map)

# %%
from transformers import GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# %%
import torch
